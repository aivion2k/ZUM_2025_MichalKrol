# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()
sys.path.append(str(PROJECT_ROOT))
sys.path.append(str(PROJECT_ROOT / "src"))

# %%
from pytorch_lightning import Trainer
from src.data.datamodule import MNISTDataModule
from src.modules.lit_cnn import LitMNISTCNN

dm = MNISTDataModule(
    data_dir=str(PROJECT_ROOT / "data"),
    batch_size=128,
    num_workers=4,
)

model = LitMNISTCNN(lr=1e-3)

trainer = Trainer(
    max_epochs=5,
    accelerator="auto",
    devices=1,
    log_every_n_steps=20,
)

trainer.fit(model, dm)
trainer.test(model, dm)
# Out:
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# /workspaces/zum_mnist_mk/.venv/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default
#
#   | Name  | Type     | Params | Mode
# -------------------------------------------
# 0 | model | MNISTCNN | 1.2 M  | train
# -------------------------------------------
# 1.2 M     Trainable params
# 0         Non-trainable params
# 1.2 M     Total params
# 4.800     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# Epoch 4: 100%|██████████| 430/430 [00:49<00:00,  8.69it/s, v_num=0, val_loss=0.0436, val_acc=0.987, train_loss=0.017, train_acc=0.994]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 430/430 [00:49<00:00,  8.68it/s, v_num=0, val_loss=0.0436, val_acc=0.987, train_loss=0.017, train_acc=0.994]
# Testing DataLoader 0: 100%|██████████| 79/79 [00:03<00:00, 23.79it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.9879000186920166
#         test_loss           0.03855914622545242
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.03855914622545242, 'test_acc': 0.9879000186920166}]
